# %%
import plotly.express as px
import pandas as pd
import numpy as np
from numpy import exp
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
from scipy import stats
from scipy.optimize import curve_fit
from scipy import asarray as ar

# %% [markdown]
# # Résultats

# %% [markdown]
# ## Distances marqueurs bas

# %%
df_data = pd.read_csv('1-Distance_2marqueurs_bas.csv')

y_data = df_data.Value
y_data_liste = list(y_data)

x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

# figure avec l'axe des x (pixels) normalisé
#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. 2D', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. Image 2D")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

# je trouve les extremums de chaque pic
y_data_500_1 = []
for i in range(500):
    y_data_500_1.append(y_data_liste[i])
y_min_1 = min(y_data_500_1)
print("le premier minimum est", y_min_1)

y_data_500_2 = []
for i in range(2700,3200):
    y_data_500_2.append(y_data_liste[i])
y_min_2 = min(y_data_500_2)
print("le deuxième minimum est", y_min_2)

# j'extrais la position en x de chaque pic
pos_x_min_1 = y_data_liste.index(y_min_1)
pos_x_min_2 = y_data_liste.index(y_min_2)

# j'extrais la valeur en x de chaque pic
x_value_at_min_1 = x_data_liste[pos_x_min_1]/range_x
x_value_at_min_2 = x_data_liste[pos_x_min_2]/range_x

# je calcule la distance entre les deux pics
dist_reference = x_value_at_min_2 - x_value_at_min_1
print("la distance entre les deux minimums est", dist_reference, "pixels")

# je calcule les nouvelles incertitudes reliées aux nouvelles valeurs et aux mesures de distance
incertitude_ref = 0.05/max(x_data_liste)
incertitude_distance_ref = np.sqrt((incertitude_ref**2) + (incertitude_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude_ref)
print("la nouvelle incertitude sur la distance est", incertitude_distance_ref)
# Out:
# le premier minimum est 8448
# le deuxième minimum est 7872
# la distance entre les deux minimums est 0.8210081497132509 pixels
# la nouvelle incertitude sur chaque mesure est 0.00015092061575611228
# la nouvelle incertitude sur la distance est 0.0002134339816439926

# %%
df_data = pd.read_csv('3-40Proj_0.5mm_distance_marqueurs_bas.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. 40 proj. - 0.5 mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. 40 proj. - 0.5 mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_200_1 = []
for i in range(200):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(800,1000):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1
print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 5.09906709907238
# le deuxième maximum est 6.56045478496551
# la distance entre les deux maximums est 0.7593320235756384 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.06167612613761242
# la nouvelle incertitude sur chaque mesure est 0.0004911591355599215
# la nouvelle incertitude sur la distance est 0.0006946039107922864
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.0007266558039459582

# %%
df_data = pd.read_csv('6-320Proj_2mm_distance_marqueurs_bas.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)


# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. 320 proj. - 2mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. 320 proj. - 2mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()


y_data_200_1 = []
for i in range(70):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(200,300):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1
print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 0.887375949792679
# le deuxième maximum est 0.982229053974152
# la distance entre les deux maximums est 0.6788079470198677 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.14220020269338318
# la nouvelle incertitude sur chaque mesure est 0.001655629139072848
# la nouvelle incertitude sur la distance est 0.0023414131827369125
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.002351120957504017

# %%
df_data = pd.read_csv('8-320Proj_0.5mm_distance_marqueurs_bas.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. 320 proj. - 0.5mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. 320 proj. - 0.5mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_200_1 = []
for i in range(150):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(750,930):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1
print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 5.14577347572033
# le deuxième maximum est 6.53712877640357
# la distance entre les deux maximums est 0.8375527426160337 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.016544592902782873
# la nouvelle incertitude sur chaque mesure est 0.0005274261603375528
# la nouvelle incertitude sur la distance est 0.0007458932290997337
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.0007758290879679855

# %%
df_data = pd.read_csv('10-320Proj_0.5mm_distance_marqueurs_bas_respiration.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait reliant les deux marqueurs du bas du fantôme. Respiration; 320 proj - 0.5mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du bas du fantôme. Respiration; 320 proj. - 0.5mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_200_1 = []
for i in range(150):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(750,930):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1
print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 4.47691011428833
# le deuxième maximum est 1.96598342003456
# la distance entre les deux maximums est 0.8386752136752137 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.017667063961962826
# la nouvelle incertitude sur chaque mesure est 0.0005341880341880342
# la nouvelle incertitude sur la distance est 0.0007554559628061406
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.0007850272455525102

# %% [markdown]
# ## Distance marqueurs hauts

# %%
df_data = pd.read_csv('2-Distance_2marquers_haut.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. 2D', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. Image 2D")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_500_1 = []
for i in range(500):
    y_data_500_1.append(y_data_liste[i])
y_min_1 = min(y_data_500_1)
print("le premier minimum est", y_min_1)

y_data_500_2 = []
for i in range(1200,1800):
    y_data_500_2.append(y_data_liste[i])
y_min_2 = min(y_data_500_2)
print("le deuxième minimum est", y_min_2)

pos_x_min_1 = y_data_liste.index(y_min_1)
pos_x_min_2 = y_data_liste.index(y_min_2)

x_value_at_min_1 = x_data_liste[pos_x_min_1]/range_x
x_value_at_min_2 = x_data_liste[pos_x_min_2]/range_x

dist_reference = x_value_at_min_2 - x_value_at_min_1
print("la distance entre les deux minimums est", dist_reference, "pixels")

incertitude_ref = 0.05/max(x_data_liste)
incertitude_distance_ref = np.sqrt((incertitude_ref**2) + (incertitude_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude_ref)
print("la nouvelle incertitude sur la distance est", incertitude_distance_ref)
# Out:
# le premier minimum est 8512
# le deuxième minimum est 10816
# la distance entre les deux minimums est 0.6933911159263273 pixels
# la nouvelle incertitude sur chaque mesure est 0.0002708559046587216
# la nouvelle incertitude sur la distance est 0.000383048093817198

# %%
df_data = pd.read_csv('4-40Proj_0.5mm_distance_marqueurs_haut.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. 40 proj. - 0.5mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. 40 proj. - 0.5mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_200_1 = []
for i in range(200):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(400,550):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1

print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 5.43117233306445
# le deuxième maximum est 4.7807779414397
# la distance entre les deux maximums est 0.5766666666666667 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.11672444925966063
# la nouvelle incertitude sur chaque mesure est 0.0008333333333333334
# la nouvelle incertitude sur la distance est 0.0011785113019775794
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.0012391992297713383

# %%
df_data = pd.read_csv('5-320Proj_2mm_distance_marqueurs_haut.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. 320 proj. - 2mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. 320 proj. - 2mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_200_1 = []
for i in range(60):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(80,160):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1
print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 0.566398606170141
# le deuxième maximum est 0.649313849541774
# la distance entre les deux maximums est 0.6094674556213019 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.0839236603050254
# la nouvelle incertitude sur chaque mesure est 0.002958579881656805
# la nouvelle incertitude sur la distance est 0.00418406379400324
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.004201561099694467

# %%
df_data = pd.read_csv('7-320Proj_0.5mm_distance_marqueurs_haut.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. 320 proj. - 0.5mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. 320 proj. - 0.5mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_200_1 = []
for i in range(200):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(400,540):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1
print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 4.1471311385815
# le deuxième maximum est 4.71378921582149
# la distance entre les deux maximums est 0.6825688073394496 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.010822308586877716
# la nouvelle incertitude sur chaque mesure est 0.0009174311926605505
# la nouvelle incertitude sur la distance est 0.0012974436352046744
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.0013528066486790007

# %%
df_data = pd.read_csv('9-320Proj_0.5mm_distance_marqueurs_haut_respiration.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

#fig = px.line(df_data, x = new_x, y = 'Value', title='Intensité en niveaux de gris du trait reliant les deux marqueurs du haut du fantôme. Respiration; 320 proj. - 0.5mm', labels={"x":"Pixels", "Value":"Intensité en niveau de gris [cd]"})
#fig.show()
plt.plot(new_x, y_data_liste)
plt.title("Intensité en niveaux de gris du trait (en pixels) reliant les deux marqueurs du haut du fantôme. Respiration; 320 proj. - 0.5mm")
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveau de gris [cd]")
plt.grid()
plt.show()

y_data_200_1 = []
for i in range(200):
    y_data_200_1.append(y_data_liste[i])
y_max_1 = max(y_data_200_1)
print("le premier maximum est", y_max_1)

y_data_200_2 = []
for i in range(400,525):
    y_data_200_2.append(y_data_liste[i])
y_max_2 = max(y_data_200_2)
print("le deuxième maximum est", y_max_2)

pos_x_max_1 = y_data_liste.index(y_max_1)
pos_x_max_2 = y_data_liste.index(y_max_2)

x_value_at_max_1 = x_data_liste[pos_x_max_1]/range_x
x_value_at_max_2 = x_data_liste[pos_x_max_2]/range_x

dist = x_value_at_max_2 - x_value_at_max_1
print("la distance entre les deux maximums est", dist, "pixels")
diff = abs(dist_reference - dist)
print("la différence avec la distance en 2D (la distance de référence) est", diff)

incertitude = 0.05/max(x_data_liste)
incertitude_distance = np.sqrt((incertitude**2) + (incertitude**2))
inc_diff_dist_avec_ref = np.sqrt((incertitude_distance**2) + (incertitude_distance_ref**2))
print("la nouvelle incertitude sur chaque mesure est", incertitude)
print("la nouvelle incertitude sur la distance est", incertitude_distance)
print("la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est", inc_diff_dist_avec_ref)
# Out:
# le premier maximum est 1.78435862047489
# le deuxième maximum est 2.4873712594986
# la distance entre les deux maximums est 0.718336483931947 pixels
# la différence avec la distance en 2D (la distance de référence) est 0.02494536800561975
# la nouvelle incertitude sur chaque mesure est 0.000945179584120983
# la nouvelle incertitude sur la distance est 0.0013366857867420558
# la nouvelle incertitude sur la différence de distance entre celle-ci et la distance en 2D (référence) est 0.0013904872292312567

# %% [markdown]
# ## Position des marqueurs avec l'effet du mouvement

# %% [markdown]
# ### Haut

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True

fig, ax1 = plt.subplots()
# graphique respiration haut
df_data = pd.read_csv('9-320Proj_0.5mm_distance_marqueurs_haut_respiration.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)
range_y = max(y_data_liste) 

new_y = []
for i in range(len(y_data_liste)):
    new_y.append(y_data_liste[i]/range_y)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

ax1.plot(new_x, new_y, color = "red", label = "Respiration")
plt.legend()
plt.xlabel("Pixels")
plt.ylabel("Intensité en niveaux de gris [cd]")
#############################

# graphique 2D haut
df_data = pd.read_csv('2-Distance_2marquers_haut.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)
range_y = max(y_data_liste) 

new_y = []
for i in range(len(y_data_liste)):
    new_y.append(y_data_liste[i]/range_y)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

ax2 = ax1.twiny()
ax2.plot(new_x, new_y, color = "blue", label = "2D")
plt.legend(loc = "upper left")
plt.title("Position et intensité lumineuse des extremums correspondant aux marqueurs du haut du fantôme")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Bas

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.rcParams["figure.autolayout"] = True

fig, ax1 = plt.subplots()

# graphique respiration bas
df_data1 = pd.read_csv('10-320Proj_0.5mm_distance_marqueurs_bas_respiration.csv')

y_data1 = df_data1.Value
y_data_liste1 = list(y_data1)
x_data1 = df_data1.Pixels
x_data_liste1 = list(x_data1)

# normalisons
range_x1 = max(x_data_liste1) - min(x_data_liste1)
range_y1 = max(y_data_liste1) 

new_y1 = []
for i in range(len(y_data_liste1)):
    new_y1.append(y_data_liste1[i]/range_y1)

new_x1 = []
for i in range(len(x_data_liste1)):
    new_x1.append(x_data_liste1[i]/range_x1)

ax1.plot(new_x1, new_y1, color = "red", label = "Intensité des pixels reliant les deux marqueurs \n du bas du fantôme avec respiration")

ymin11 = []
for i in range(450):
    ymin11.append(new_y1[i])

ymin21 = []
for i in range(450,930):
    ymin21.append(new_y1[i])

plt.plot(new_x1[new_y1.index(max(ymin11))], max(ymin11), ".", color = "black")
plt.plot(new_x1[new_y1.index(max(ymin21))], max(ymin21), ".", color = "black", label = "Maximums d'intensité pour la reconstruction 3D \n avec respiration (position des marqueurs)")


plt.xlabel("Pixels")
plt.ylabel("Intensité en niveaux de gris [cd]")
#############################

# graphique 2D bas
df_data = pd.read_csv('1-Distance_2marqueurs_bas.csv')

y_data = df_data.Value
y_data_liste = list(y_data)
x_data = df_data.Pixels
x_data_liste = list(x_data)

# normalisons
range_x = max(x_data_liste) - min(x_data_liste)
range_y = max(y_data_liste) 

new_y = []
for i in range(len(y_data_liste)):
    new_y.append(y_data_liste[i]/range_y)

new_x = []
for i in range(len(x_data_liste)):
    new_x.append(x_data_liste[i]/range_x)

# je trouve le premier et le deuxieme minimum pour tracer des lignes verticales pour la représentation
ymin1 = []
for i in range(1500):
    ymin1.append(new_y[i])

ymin2 = []
for i in range(1600,3300):
    ymin2.append(new_y[i])


plt.plot(new_x, new_y, color = "blue", label = "Intensité des pixels reliant les deux marqueurs \n du bas du fantôme; image 2D")
plt.plot(new_x[new_y.index(min(ymin1))], min(ymin1), ".", color = "green", label = "Minimum d'intensité pour l'image 2D (positions des marqueurs)" )
plt.plot(new_x[new_y.index(min(ymin2))], min(ymin2), ".", color = "green")

plt.legend(loc = "center")
plt.title("Position et intensité lumineuse des extremums correspondant aux marqueurs du bas du fantôme")
ax2 = ax1.twiny()
ax2.plot(new_x, new_y, color = "blue", label = "Intensité des pixels reliant les deux marqueurs du bas du fantôme; image 2D")
plt.plot(new_x[new_y.index(min(ymin1))], min(ymin1), ".", color = "green", label = "Minimum d'intensité pour l'image 2D (positions des marqueurs)" )
plt.plot(new_x[new_y.index(min(ymin2))], min(ymin2), ".", color = "green")
plt.errorbar(new_x1[new_y1.index(max(ymin11))], max(ymin11), xerr=0.0005, fmt='.k', capsize=4)
plt.errorbar(new_x1[new_y1.index(max(ymin21))], max(ymin21), xerr=0.0005, fmt='.k', capsize=4)
plt.errorbar(new_x[new_y.index(min(ymin1))], min(ymin1), xerr=0.0002, capsize=4, color="green")
plt.errorbar(new_x[new_y.index(min(ymin2))], min(ymin2), xerr=0.0002, capsize=4, color="green")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
